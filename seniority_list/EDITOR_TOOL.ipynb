# %% [markdown]
# ## Editor Tool using a Bokeh server

# %%
# uncomment for wider display:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %%time
from functools import partial
import editor_function as ef

from bokeh.resources import INLINE
from bokeh.io import show, output_notebook

from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application
# Out:
# CPU times: user 704 ms, sys: 44 ms, total: 748 ms
# Wall time: 753 ms

# %%
# %%time
# reverse the commented line below for offline, online...

#output_notebook(INLINE)
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0d7e8289-69e0-4ab4-adfa-83398886445f">Loading BokehJS ...</span>
#     </div>
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 4.05 ms

# %% [markdown]
# The editor_function function defines the app.  Arguments to the function are passed using the functools partial method.

# %%
# %%time
handler = FunctionHandler(partial(ef.editor,
                                  #insert editor function arguments here as desired...
                                 ))
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 196 µs

# %%
# %%time
app = Application(handler)
show(app)
# Out:
# <script
#     src="http://localhost:43271/autoload.js?bokeh-autoload-element=34b80b7e-2f02-435e-b99d-d180f79ebf1e&bokeh-absolute-url=http://localhost:43271"
#     id="34b80b7e-2f02-435e-b99d-d180f79ebf1e"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>
# CPU times: user 16 ms, sys: 12 ms, total: 28 ms
# Wall time: 27.3 ms
